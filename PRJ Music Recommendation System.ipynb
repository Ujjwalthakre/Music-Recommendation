# %%
import pandas as pd
import numpy as np

# %%
import os 
os.chdir ('C:\Projects\Music Recomm//')
import Recommenders as Recommenders

# %%
song_df_1 = pd.read_csv('triplets_file.csv')
print (song_df_1.shape)
print (song_df_1.head())
# Out:
# (2000000, 3)
#                                     user_id             song_id  listen_count
# 0  b80344d063b5ccb3212f76538f3d9e43d87dca9e  SOAKIMP12A8C130995             1
# 1  b80344d063b5ccb3212f76538f3d9e43d87dca9e  SOBBMDR12A8C13253B             2
# 2  b80344d063b5ccb3212f76538f3d9e43d87dca9e  SOBXHDL12A81C204C0             1
# 3  b80344d063b5ccb3212f76538f3d9e43d87dca9e  SOBYHAJ12A6701BF1D             1
# 4  b80344d063b5ccb3212f76538f3d9e43d87dca9e  SODACBL12A8C13C273             1

# %%
song_df_2 = pd.read_csv('song_data.csv')
print (song_df_2.shape)
display  (song_df_2.head())
# Out:
# (1000000, 5)
#               song_id              title
# 0  SOQMMHC12AB0180CB8       Silent Night  \
# 1  SOVFVAK12A8C1350D9        Tanssi vaan
# 2  SOGTUKN12AB017F4F1  No One Could Ever
# 3  SOBNYVR12A8C13558C      Si Vos Querés
# 4  SOHSBXH12A8C13B0DF   Tangle Of Aspens
#
#                                 release       artist_name  year
# 0                 Monster Ballads X-Mas  Faster Pussy cat  2003
# 1                           Karkuteillä  Karkkiautomaatti  1995
# 2                                Butter    Hudson Mohawke  2006
# 3                               De Culo       Yerba Brava  2003
# 4  Rene Ablaze Presents Winter Sessions        Der Mystic     0

# %%
song_df = pd.merge(song_df_1, song_df_2.drop_duplicates(['song_id']), on='song_id', how='left')
display (song_df.shape)
display (song_df.head())
# Out:
# (2000000, 7)
#                                     user_id             song_id  listen_count
# 0  b80344d063b5ccb3212f76538f3d9e43d87dca9e  SOAKIMP12A8C130995             1  \
# 1  b80344d063b5ccb3212f76538f3d9e43d87dca9e  SOBBMDR12A8C13253B             2
# 2  b80344d063b5ccb3212f76538f3d9e43d87dca9e  SOBXHDL12A81C204C0             1
# 3  b80344d063b5ccb3212f76538f3d9e43d87dca9e  SOBYHAJ12A6701BF1D             1
# 4  b80344d063b5ccb3212f76538f3d9e43d87dca9e  SODACBL12A8C13C273             1
#
#              title                        release    artist_name  year
# 0         The Cove             Thicker Than Water   Jack Johnson     0
# 1  Entre Dos Aguas            Flamenco Para Niños  Paco De Lucia  1976
# 2         Stronger                     Graduation     Kanye West  2007
# 3   Constellations              In Between Dreams   Jack Johnson  2005
# 4     Learn To Fly  There Is Nothing Left To Lose   Foo Fighters  1999

# %%
print(len(song_df_1), len(song_df_2))
# Out:
# 2000000 1000000

# %%
len(song_df)
# Out:
# 2000000

# %%
song_df = song_df.head(50000)
song_df.shape
# Out:
# (50000, 7)

# %%
song_df['song'] = song_df['title']+' - '+song_df['release']
song_df.head()
# Out:
#                                     user_id             song_id  listen_count
# 0  b80344d063b5ccb3212f76538f3d9e43d87dca9e  SOAKIMP12A8C130995             1  \
# 1  b80344d063b5ccb3212f76538f3d9e43d87dca9e  SOBBMDR12A8C13253B             2
# 2  b80344d063b5ccb3212f76538f3d9e43d87dca9e  SOBXHDL12A81C204C0             1
# 3  b80344d063b5ccb3212f76538f3d9e43d87dca9e  SOBYHAJ12A6701BF1D             1
# 4  b80344d063b5ccb3212f76538f3d9e43d87dca9e  SODACBL12A8C13C273             1
#
#              title                        release    artist_name  year
# 0         The Cove             Thicker Than Water   Jack Johnson     0  \
# 1  Entre Dos Aguas            Flamenco Para Niños  Paco De Lucia  1976
# 2         Stronger                     Graduation     Kanye West  2007
# 3   Constellations              In Between Dreams   Jack Johnson  2005
# 4     Learn To Fly  There Is Nothing Left To Lose   Foo Fighters  1999
#
#                                            song
# ...

# %%
song_grouped = song_df.groupby(['song']).agg({'listen_count':'count'}).reset_index()
song_grouped.head()
# Out:
#                                                 song  listen_count
# 0  #!*@ You Tonight [Featuring R. Kelly] (Explici...             1
# 1                           #40 - Listener Supported             7
# 2                          & Down - Oi Oi oi REMIXED            13
# 3  ' Cello Song - Way To Blue - An Introduction T...             3
# 4             '97 Bonnie & Clyde - The Slim Shady LP             5

# %%
grouped_sum = song_grouped['listen_count'].sum()
grouped_sum
# Out:
# 50000

# %%
song_grouped['percentage'] = (song_grouped['listen_count'] / grouped_sum ) * 100
song_grouped.sort_values(['listen_count', 'song'], ascending=[0,1])
# Out:
#                                                    song  listen_count
# 6704                 Sehr kosmisch - Musik von Harmonia           204  \
# 8532                             Undo - Vespertine Live           182
# 1935  Dog Days Are Over (Radio Edit) - Now That's Wh...           173
# 9280                You're The One - If There Was A Way           169
# 6370                        Revelry - Only By The Night           166
# ...                                                 ...           ...
# 9314                  Your Time Has Come - Out Of Exile             1
# 9324  Zebra (full-length/album version) - Sunrise Ov...             1
# 9335                     clouding - Everything Ecstatic             1
# 9336                   high fives - Everything Ecstatic             1
# 9345                   the Love Song - Joyful Rebellion             1
#
#       percentage
# 6704       0.408
# 8532       0.364
# 1935       0.346
# 9280       0.338
# 6370       0.332
# ...

# %%
pr = Recommenders.popularity_recommender_py()
pr.create(song_df, 'user_id', 'song')

# %%
pr.recommend(song_df['user_id'][5])
# Out:
#                                        user_id
# 6704  b80344d063b5ccb3212f76538f3d9e43d87dca9e  \
# 8532  b80344d063b5ccb3212f76538f3d9e43d87dca9e
# 1935  b80344d063b5ccb3212f76538f3d9e43d87dca9e
# 9280  b80344d063b5ccb3212f76538f3d9e43d87dca9e
# 6370  b80344d063b5ccb3212f76538f3d9e43d87dca9e
# 6693  b80344d063b5ccb3212f76538f3d9e43d87dca9e
# 3380  b80344d063b5ccb3212f76538f3d9e43d87dca9e
# 2534  b80344d063b5ccb3212f76538f3d9e43d87dca9e
# 8309  b80344d063b5ccb3212f76538f3d9e43d87dca9e
# 3260  b80344d063b5ccb3212f76538f3d9e43d87dca9e
#
#                                                    song  score  Rank
# 6704                 Sehr kosmisch - Musik von Harmonia    204   1.0
# 8532                             Undo - Vespertine Live    182   2.0
# 1935  Dog Days Are Over (Radio Edit) - Now That's Wh...    173   3.0
# 9280                You're The One - If There Was A Way    169   4.0
# 6370                        Revelry - Only By The Night    166   5.0
# ...

# %%
pr.recommend(song_df['user_id'][100])
# Out:
#                                        user_id
# 6704  e006b1a48f466bf59feefed32bec6494495a4436  \
# 8532  e006b1a48f466bf59feefed32bec6494495a4436
# 1935  e006b1a48f466bf59feefed32bec6494495a4436
# 9280  e006b1a48f466bf59feefed32bec6494495a4436
# 6370  e006b1a48f466bf59feefed32bec6494495a4436
# 6693  e006b1a48f466bf59feefed32bec6494495a4436
# 3380  e006b1a48f466bf59feefed32bec6494495a4436
# 2534  e006b1a48f466bf59feefed32bec6494495a4436
# 8309  e006b1a48f466bf59feefed32bec6494495a4436
# 3260  e006b1a48f466bf59feefed32bec6494495a4436
#
#                                                    song  score  Rank
# 6704                 Sehr kosmisch - Musik von Harmonia    204   1.0
# 8532                             Undo - Vespertine Live    182   2.0
# 1935  Dog Days Are Over (Radio Edit) - Now That's Wh...    173   3.0
# 9280                You're The One - If There Was A Way    169   4.0
# 6370                        Revelry - Only By The Night    166   5.0
# ...

# %%
ir = Recommenders.item_similarity_recommender_py()
ir.create(song_df, 'user_id', 'song')

# %%
user_items = ir.get_user_items(song_df['user_id'][5])
# display user songs history
for user_item in user_items:
    print(user_item)
# Out:
# The Cove - Thicker Than Water
# Entre Dos Aguas - Flamenco Para Niños
# Stronger - Graduation
# Constellations - In Between Dreams
# Learn To Fly - There Is Nothing Left To Lose
# Apuesta Por El Rock 'N' Roll - Antología Audiovisual
# Paper Gangsta - The Fame Monster
# Stacked Actors - There Is Nothing Left To Lose
# Sehr kosmisch - Musik von Harmonia
# Heaven's gonna burn your eyes - Hôtel Costes 7 by Stéphane Pompougnac
# Let It Be Sung - If I Had Eyes
# I'll Be Missing You (Featuring Faith Evans & 112)(Album Version) - No Way Out
# Love Shack - Original Hits - Rock
# Clarity - As/Is: Cleveland/Cincinnati_ OH - 8/03-8/04/04
# I?'m A Steady Rollin? Man - Diggin' Deeper Volume 7
# The Old Saloon - Incredibad
# Behind The Sea [Live In Chicago] - Live In Chicago
# Champion - Graduation
# Breakout - There Is Nothing Left To Lose
# Ragged Wood - Fleet Foxes
# Mykonos - Sun Giant
# Country Road - En Concert
# Oh No - Noble Beast
# Love Song For No One - Room For Squares
# ...

# %%
user_items = ir.get_user_items(song_df['user_id'][100])
# display user songs history
for user_item in user_items:
    print(user_item)
# Out:
# Undo - Vespertine Live
# Dog Days Are Over (Radio Edit) - Now That's What I Call Music! 75
# High Life - Discovery
# You're The One - If There Was A Way
# Where Did You Sleep Last Night - MTV Unplugged In New York
# Come As You Are - Nirvana
# Hey_ Soul Sister - Save Me_ San Francisco
# Horn Concerto No. 4 in E flat K495: II. Romance (Andante cantabile) - Mozart - Eine kleine Nachtmusik
# Rhyme & Reason - Listener Supported
# Sehr kosmisch - Musik von Harmonia
# Someone Else's Arms - Everglow_ The
# Cry For Help (Album Version) - The Sound of Madness [Deluxe]
# Lady In Black - One More Magic Potion
# For You (Amended/Radio Edit LP) - The Singles
# Fireflies - Karaoke Monthly Vol. 2 (January 2010)
# Secrets - Waking Up
# Esta Es Para Hacerte Féliz - Esta Es Para Hacerte Feliz
# Revelry - Only By The Night
# Marry Me - Save Me_ San Francisco
# OMG - OMG - The Remixes
# Drop The World - Drop The World
# Ain't Misbehavin - Summertime
# ...

# %%
ir.recommend(song_df['user_id'][5])
# Out:
# No. of unique songs for the user: 45
# no. of unique songs in the training set: 9349
# Non zero values in cooccurence_matrix :27511
#                                     user_id
# 0  b80344d063b5ccb3212f76538f3d9e43d87dca9e  \
# 1  b80344d063b5ccb3212f76538f3d9e43d87dca9e
# 2  b80344d063b5ccb3212f76538f3d9e43d87dca9e
# 3  b80344d063b5ccb3212f76538f3d9e43d87dca9e
# 4  b80344d063b5ccb3212f76538f3d9e43d87dca9e
# 5  b80344d063b5ccb3212f76538f3d9e43d87dca9e
# 6  b80344d063b5ccb3212f76538f3d9e43d87dca9e
# 7  b80344d063b5ccb3212f76538f3d9e43d87dca9e
# 8  b80344d063b5ccb3212f76538f3d9e43d87dca9e
# 9  b80344d063b5ccb3212f76538f3d9e43d87dca9e
#
#                                                 song     score  rank
# 0  Questions - Sing-A-Longs & Lullabies For The F...  0.040331     1
# 1  Wrong Turn - Sing-A-Longs & Lullabies For The ...  0.039915     2
# 2                     Ghost Dream - Hymie's Basement  0.039056     3
# 3                   Great Indoors - Room For Squares  0.038541     4
# ...

# %%
ir.recommend(song_df['user_id'][100])
# Out:
# No. of unique songs for the user: 25
# no. of unique songs in the training set: 9349
# Non zero values in cooccurence_matrix :47304
#                                     user_id
# 0  e006b1a48f466bf59feefed32bec6494495a4436  \
# 1  e006b1a48f466bf59feefed32bec6494495a4436
# 2  e006b1a48f466bf59feefed32bec6494495a4436
# 3  e006b1a48f466bf59feefed32bec6494495a4436
# 4  e006b1a48f466bf59feefed32bec6494495a4436
# 5  e006b1a48f466bf59feefed32bec6494495a4436
# 6  e006b1a48f466bf59feefed32bec6494495a4436
# 7  e006b1a48f466bf59feefed32bec6494495a4436
# 8  e006b1a48f466bf59feefed32bec6494495a4436
# 9  e006b1a48f466bf59feefed32bec6494495a4436
#
#                                                 song     score  rank
# 0  Lucky (Album Version) - We Sing.  We Dance.  W...  0.099839     1
# 1  Pursuit Of Happiness (nightmare) - Pursuit Of ...  0.097587     2
# 2                       Somebody To Love - My Worlds  0.089141     3
# 3                Heartbreak Warfare - Battle Studies  0.089083     4
# ...

# %%
ir.get_similar_items(['Trial And Error', 'Le Volume Ã‰tait Au Maximum'])
# Out:
# no. of unique songs in the training set: 9349
# Non zero values in cooccurence_matrix :0
#   user_id                                               song  score  rank
# 0                                          Rapture - Poetica    0.0     1
# 1          King Of My Castle [Nicola Fasano & Steve Fores...    0.0     2
# 2                         One More Step To Take - Collection    0.0     3
# 3          How It Makes You Feel - The Real Thing Words &...    0.0     4
# 4          Fuori Dal Tunnel (Album Version) - Verità Supp...    0.0     5
# 5                    Shooter - The Evolution of Robin Thicke    0.0     6
# 6                              Break Up To Make Up - Jeremih    0.0     7
# 7                                  Opus No. 12 - Piano Solos    0.0     8
# 8                            Watch Over You - Watch Over You    0.0     9
# 9                                       Arise - Memento Mori    0.0    10

# %%
ir.get_similar_items(['I Miss You' ,'De Culo'])
# Out:
# no. of unique songs in the training set: 9349
# Non zero values in cooccurence_matrix :0
#   user_id                                               song  score  rank
# 0                                          Rapture - Poetica    0.0     1
# 1          King Of My Castle [Nicola Fasano & Steve Fores...    0.0     2
# 2                         One More Step To Take - Collection    0.0     3
# 3          How It Makes You Feel - The Real Thing Words &...    0.0     4
# 4          Fuori Dal Tunnel (Album Version) - Verità Supp...    0.0     5
# 5                    Shooter - The Evolution of Robin Thicke    0.0     6
# 6                              Break Up To Make Up - Jeremih    0.0     7
# 7                                  Opus No. 12 - Piano Solos    0.0     8
# 8                            Watch Over You - Watch Over You    0.0     9
# 9                                       Arise - Memento Mori    0.0    10

# %%
ir.get_similar_items(['Symphony No. 1 G minor "Sinfonie Serieuse"/Allegro con energia','David Montgomery'])
# Out:
# no. of unique songs in the training set: 9349
# Non zero values in cooccurence_matrix :0
#   user_id                                               song  score  rank
# 0                                          Rapture - Poetica    0.0     1
# 1          King Of My Castle [Nicola Fasano & Steve Fores...    0.0     2
# 2                         One More Step To Take - Collection    0.0     3
# 3          How It Makes You Feel - The Real Thing Words &...    0.0     4
# 4          Fuori Dal Tunnel (Album Version) - Verità Supp...    0.0     5
# 5                    Shooter - The Evolution of Robin Thicke    0.0     6
# 6                              Break Up To Make Up - Jeremih    0.0     7
# 7                                  Opus No. 12 - Piano Solos    0.0     8
# 8                            Watch Over You - Watch Over You    0.0     9
# 9                                       Arise - Memento Mori    0.0    10
